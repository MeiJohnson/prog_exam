# %%
# %%sh
#
# pip install yargy # для обработки текста
# pip install natasha # для обработки текста
# pip install wordcloud # для создания изображения с облаком тегов
# Out:
# Collecting yargy
#   Downloading yargy-0.15.0-py3-none-any.whl (41 kB)
# Collecting pymorphy2
#   Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
# Requirement already satisfied: docopt>=0.6 in /usr/local/lib/python3.7/dist-packages (from pymorphy2->yargy) (0.6.2)
# Collecting dawg-python>=0.7.1
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
# Installing collected packages: pymorphy2-dicts-ru, dawg-python, pymorphy2, yargy
# Successfully installed dawg-python-0.7.2 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844 yargy-0.15.0
# Collecting natasha
#   Downloading natasha-1.4.0-py3-none-any.whl (34.4 MB)
# Collecting slovnet>=0.3.0
#   Downloading slovnet-0.5.0-py3-none-any.whl (49 kB)
# Collecting razdel>=0.5.0
#   Downloading razdel-0.5.0-py3-none-any.whl (21 kB)
# Collecting navec>=0.9.0
#   Downloading navec-0.10.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: pymorphy2 in /usr/local/lib/python3.7/dist-packages (from natasha) (0.9.1)
# Requirement already satisfied: yargy>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from natasha) (0.15.0)
# Collecting ipymarkup>=0.8.0
#   Downloading ipymarkup-0.9.0-py3-none-any.whl (14 kB)
# Collecting intervaltree>=3
#   Downloading intervaltree-3.1.0.tar.gz (32 kB)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from intervaltree>=3->ipymarkup>=0.8.0->natasha) (2.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from navec>=0.9.0->natasha) (1.19.5)
# Requirement already satisfied: dawg-python>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from pymorphy2->natasha) (0.7.2)
# Requirement already satisfied: docopt>=0.6 in /usr/local/lib/python3.7/dist-packages (from pymorphy2->natasha) (0.6.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from pymorphy2->natasha) (2.4.417127.4579844)
# Building wheels for collected packages: intervaltree
#   Building wheel for intervaltree (setup.py): started
#   Building wheel for intervaltree (setup.py): finished with status 'done'
#   Created wheel for intervaltree: filename=intervaltree-3.1.0-py2.py3-none-any.whl size=26119 sha256=30ef7a2a7f47f49ed6c2c184feb873fb5588a1a2521c6eba80044820343c7e08
#   Stored in directory: /root/.cache/pip/wheels/16/85/bd/1001cbb46dcfb71c2001cd7401c6fb250392f22a81ce3722f7
# Successfully built intervaltree
# Installing collected packages: razdel, navec, intervaltree, slovnet, ipymarkup, natasha
#   Attempting uninstall: intervaltree
#     Found existing installation: intervaltree 2.1.0
#     Uninstalling intervaltree-2.1.0:
#       Successfully uninstalled intervaltree-2.1.0
# Successfully installed intervaltree-3.1.0 ipymarkup-0.9.0 natasha-1.4.0 navec-0.10.0 razdel-0.5.0 slovnet-0.5.0
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from wordcloud) (7.1.2)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from wordcloud) (1.19.5)

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen('https://www.herzen.spb.ru/main/facts/nowadays/1558542985/1559574321/')
bs = BeautifulSoup(html.read(), 'html.parser')
# print(bs)

# %%
import re

# %%
news_href = []
for news in bs.find_all(href=re.compile("https://www.herzen.spb.ru/news/*")):
  # print(news.get('href'))
  news_href.append(news.get('href'))
print(news_href) # получили список ссылок на новости
# Out:
# ['https://www.herzen.spb.ru/news/31-07-2020/', 'https://www.herzen.spb.ru/news/15-11-2019_10/', 'https://www.herzen.spb.ru/news/15-11-2019_1/', 'https://www.herzen.spb.ru/news/06-11-2019_6/', 'https://www.herzen.spb.ru/news/31-10-2019_1/', 'https://www.herzen.spb.ru/news/30-10-2019_3/', 'https://www.herzen.spb.ru/news/30-10-2019_4/', 'https://www.herzen.spb.ru/news/30-10-2019_5/', 'https://www.herzen.spb.ru/news/14-10-2019_7/', 'https://www.herzen.spb.ru/news/17-10-2019_6/', 'https://www.herzen.spb.ru/news/07-09-2019/', 'https://www.herzen.spb.ru/news/23-08-2019_2/', 'https://www.herzen.spb.ru/news/19-08-2019_2/', 'https://www.herzen.spb.ru/news/19-08-2019/', 'https://www.herzen.spb.ru/news/16-08-2019_1/', 'https://www.herzen.spb.ru/news/12-08-2019_3/', 'https://www.herzen.spb.ru/news/12-08-2019_2/', 'https://www.herzen.spb.ru/news/12-08-2019/', 'https://www.herzen.spb.ru/news/12-08-2019_1/', 'https://www.herzen.spb.ru/news/26-08-2019/', 'https://www.herzen.spb.ru/news/06-08-2019/', 'https://www.herzen.spb.ru/news/02-08-2019_1/', 'https://www.herzen.spb.ru/news/02-08-2019/', 'https://www.herzen.spb.ru/news/31-07-2019/', 'https://www.herzen.spb.ru/news/26-07-2019_1/', 'https://www.herzen.spb.ru/news/27-07-2019/', 'https://www.herzen.spb.ru/news/24-07-2019/', 'https://www.herzen.spb.ru/news/22-07-2019_2/', 'https://www.herzen.spb.ru/news/22-07-2019_1/', 'https://www.herzen.spb.ru/news/17-07-2019_3/', 'https://www.herzen.spb.ru/news/17-07-2019_6/', 'https://www.herzen.spb.ru/news/17-07-2019_5/', 'https://www.herzen.spb.ru/news/15-07-2019_1/', 'https://www.herzen.spb.ru/news/15-07-2019/', 'https://www.herzen.spb.ru/news/11-07-2019_1/', 'https://www.herzen.spb.ru/news/12-07-2019_5/', 'https://www.herzen.spb.ru/news/09-07-2019/', 'https://www.herzen.spb.ru/news/08-07-2019_8/', 'https://www.herzen.spb.ru/news/06-07-2019/', 'https://www.herzen.spb.ru/news/08-07-2019_6/', 'https://www.herzen.spb.ru/news/08-07-2019_2/', 'https://www.herzen.spb.ru/news/01-07-2019_1/', 'https://www.herzen.spb.ru/news/02-07-2019/', 'https://www.herzen.spb.ru/news/01-07-2019_2/', 'https://www.herzen.spb.ru/news/28-06-2019_1/', 'https://www.herzen.spb.ru/news/28-06-2019_2/', 'https://www.herzen.spb.ru/news/25-06-2019_2/', 'https://www.herzen.spb.ru/news/24-06-2019_2/', 'https://www.herzen.spb.ru/news/24-06-2019/', 'https://www.herzen.spb.ru/news/24-06-2019_1/', 'https://www.herzen.spb.ru/news/20-06-2019_2/', 'https://www.herzen.spb.ru/news/20-06-2019/', 'https://www.herzen.spb.ru/news/21-06-2019_5/', 'https://www.herzen.spb.ru/news/21-06-2019_6/', 'https://www.herzen.spb.ru/news/17-06-2019_2/', 'https://www.herzen.spb.ru/news/16-06-2019/', 'https://www.herzen.spb.ru/news/17-06-2019_1/', 'https://www.herzen.spb.ru/news/17-06-2019/', 'https://www.herzen.spb.ru/news/13-06-2019/', 'https://www.herzen.spb.ru/news/10-06-2019_12/', 'https://www.herzen.spb.ru/news/10-06-2019_2/', 'https://www.herzen.spb.ru/news/10-06-2019_6/', 'https://www.herzen.spb.ru/news/10-06-2019_1/', 'https://www.herzen.spb.ru/news/07-06-2019_5/', 'https://www.herzen.spb.ru/news/07-06-2019_4/', 'https://www.herzen.spb.ru/news/07-06-2019_3/', 'https://www.herzen.spb.ru/news/03-06-2019/']

# %%
#for link in news_href:
#  page = urlopen(link)
#  raw_page = BeautifulSoup(page.read(), 'html.parser')
#  print(raw_page)


page = urlopen(news_href[0])
raw_page = BeautifulSoup(page.read(), 'html.parser')
# print(raw_page)
news_table = raw_page.find(class_='blockwh')
# print(news_table)
news_text_arr = news_table.find_all('p')
# print(news_text_arr)
news_text = ""
for i in range(3,len(news_text_arr)):
  news_text+=(str(news_text_arr[i].contents[0]))

print(news_text)
# Out:
# В этом году пандемия внесла коррективы во многие планы. Однако все равно не смогла помешать открытию вторых летних Педагогических сезонов.Открытие состоялось в формате онлайн, к которому за последние месяцы мы все уже привыкли. Тем более, что тема первой дискуссии – Старт первым Сезонам в прошлом году давал губернатор Санкт-Петербурга. В этом году с вступительным словом к участникам, партнерам и организаторам проекта обратился <em>«Мне почётно быть в партнерстве с вами, с теми, кто действительно делает актуальную педагогику в нашем городе, готовит и выпускает учителей, и кто олицетворяет одну из старейших и развитых педагогических школ нашей страны</em>Анализируя опыт Сезонов прошлого года, вице-губернатор сказал, что Герценовский университет показал возможности контактной педагогики, в очередной раз став активным участником жизни города.Ректор РГПУ им. А. И. Герцена Он также анонсировал открытие 1 сентября «Точки кипения» — живого пространства для встреч и общения и пообещал, что программа будет очень интересной.Сергей Игоревич выразил надежду, что в ближайшее время мы все вернемся к привычному для нас формату реального общения и рассказал, что вскоре исторические ворота XYIII века на Мойке, 48 будут открыты для посетителей Педагогических сезонов.<em>«Мы по-прежнему остаемся открытым кампусом, даже более открытым, чем это было раньше. Потому что сейчас мы видим новые возможности, которые возникли в ситуации ограничений»</em>Завершил официальную часть открытия проректор Герценовского университета  <img src="https://sun9-63.userapi.com/41TOBaIFmaF7jLK6tAzggm0_bN_NGh7Hbohtow/p8Bmoxpwfsc.jpg" style="height:281px; width:500px"/> <em>«Нельзя закрыть знания на замок, нельзя не обращать внимание на то, что происходит вокруг. Мы хотим быть полезными своим опытом и знаниями в решении ваших задач и проблем. Мы бы хотели, чтобы в рамках Педагогических сезонов вы нашли своего «значимого взрослого» — того, кто поможет вам стать лучше, опытнее, в чем-то осведомлённее, чтобы вы развивали свои компетенции и стремились к тому уровню, который действительно будет достойным результатом ваших трудов и работ»,</em>Дальнейшая дискуссия, которая собственно и дала старт Сезонам этого года, была посвящена достижениям в области внедрения новых форматов обучения. Представители профессионального сообщества приняли участие в диалоге, а также обсудили, как в наступающем учебном году будут применяться дистанционные форматы в школах и вузах нашей страны.<strong>Поздравляем всех с началом новых Педагогических сезонов и ждем вас в нашем виртуальном кампусе!</strong>

# %%
"""
news_text = raw_page.find_all('p')
post = ''
for el in news_text:
  post+=el.get_text()
#  print(el.get_text())
# print(news_text)
#print(post)
# a = re.split(r'\n',post)
"""

from natasha import (
    Segmenter,
    MorphVocab,
    
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,
    
    PER,
    NamesExtractor,

    Doc
)

segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

names_extractor = NamesExtractor(morph_vocab)

doc = Doc(news_text)
doc.segment(segmenter)
doc.tag_morph(morph_tagger)
doc.parse_syntax(syntax_parser)

doc.tag_ner(ner_tagger)

for span in doc.spans:
    span.normalize(morph_vocab)
    
for token in doc.tokens:
  token.lemmatize(morph_vocab)
print({_.text: _.lemma for _ in doc.tokens})
# Out:
# {'В': 'в', 'этом': 'этот', 'году': 'год', 'пандемия': 'пандемия', 'внесла': 'внести', 'коррективы': 'корректив', 'во': 'в', 'многие': 'многий', 'планы': 'план', '.': '.', 'Однако': 'однако', 'все': 'весь', 'равно': 'равный', 'не': 'не', 'смогла': 'смочь', 'помешать': 'помешать', 'открытию': 'открытие', 'вторых': 'второй', 'летних': 'летний', 'Педагогических': 'педагогический', 'сезонов': 'сезон', 'Открытие': 'открытие', 'состоялось': 'состояться', 'в': 'в', 'формате': 'формат', 'онлайн': 'онлайн', ',': ',', 'к': 'к', 'которому': 'который', 'за': 'за', 'последние': 'последний', 'месяцы': 'месяц', 'мы': 'мы', 'уже': 'уже', 'привыкли': 'привыкнуть', 'Тем': 'тот', 'более': 'более', 'что': 'что', 'тема': 'тема', 'первой': 'первый', 'дискуссии': 'дискуссия', '–': '–', 'Старт': 'старт', 'первым': 'первый', 'Сезонам': 'сезон', 'прошлом': 'прошлый', 'давал': 'давать', 'губернатор': 'губернатор', 'Санкт-Петербурга': 'санкт-петербург', 'с': 'с', 'вступительным': 'вступительный', 'словом': 'слово', 'участникам': 'участник', 'партнерам': 'партнер', 'и': 'и', 'организаторам': 'организатор', 'проекта': 'проект', 'обратился': 'обратиться', '<': '<', 'em': 'em', '>': '>', '«': '«', 'Мне': 'я', 'почётно': 'почетный', 'быть': 'быть', 'партнерстве': 'партнерство', 'вами': 'вы', 'теми': 'тот', 'кто': 'кто', 'действительно': 'действительно', 'делает': 'делать', 'актуальную': 'актуальный', 'педагогику': 'педагогика', 'нашем': 'наш', 'городе': 'город', 'готовит': 'готовить', 'выпускает': 'выпускать', 'учителей': 'учитель', 'олицетворяет': 'олицетворять', 'одну': 'один', 'из': 'из', 'старейших': 'старый', 'развитых': 'развить', 'педагогических': 'педагогический', 'школ': 'школа', 'нашей': 'наш', 'страны': 'страна', '/': '/', 'Анализируя': 'анализировать', 'опыт': 'опыт', 'Сезонов': 'сезон', 'прошлого': 'прошлый', 'года': 'год', 'вице-губернатор': 'вице-губернатор', 'сказал': 'сказать', 'Герценовский': 'герценовский', 'университет': 'университет', 'показал': 'показать', 'возможности': 'возможность', 'контактной': 'контактный', 'педагогики': 'педагогика', 'очередной': 'очередной', 'раз': 'раз', 'став': 'стать', 'активным': 'активный', 'участником': 'участник', 'жизни': 'жизнь', 'города': 'город', 'Ректор': 'ректор', 'РГПУ': 'ргпу', 'им': 'имя', 'А': 'а', 'И': 'и', 'Герцена': 'герцен', 'Он': 'он', 'также': 'также', 'анонсировал': 'анонсировать', 'открытие': 'открытие', '1': '1', 'сентября': 'сентябрь', 'Точки': 'точка', 'кипения': 'кипение', '»': '»', '—': '—', 'живого': 'живой', 'пространства': 'пространство', 'для': 'для', 'встреч': 'встреча', 'общения': 'общение', 'пообещал': 'пообещать', 'программа': 'программа', 'будет': 'быть', 'очень': 'очень', 'интересной': 'интересный', 'Сергей': 'сергей', 'Игоревич': 'игоревич', 'выразил': 'выразить', 'надежду': 'надежда', 'ближайшее': 'близкий', 'время': 'время', 'вернемся': 'вернуться', 'привычному': 'привычный', 'нас': 'мы', 'формату': 'формат', 'реального': 'реальный', 'рассказал': 'рассказать', 'вскоре': 'вскоре', 'исторические': 'исторический', 'ворота': 'ворота', 'XYIII': 'xyiii', 'века': 'век', 'на': 'на', 'Мойке': 'мойка', '48': '48', 'будут': 'быть', 'открыты': 'открыть', 'посетителей': 'посетитель', 'Мы': 'мы', 'по-прежнему': 'по-прежнему', 'остаемся': 'оставаться', 'открытым': 'открытый', 'кампусом': 'кампус', 'даже': 'даже', 'чем': 'чем', 'это': 'это', 'было': 'быть', 'раньше': 'ранний', 'Потому': 'потому', 'сейчас': 'сейчас', 'видим': 'видеть', 'новые': 'новый', 'которые': 'который', 'возникли': 'возникнуть', 'ситуации': 'ситуация', 'ограничений': 'ограничение', 'Завершил': 'завершить', 'официальную': 'официальный', 'часть': 'часть', 'открытия': 'открытие', 'проректор': 'проректор', 'Герценовского': 'герценовский', 'университета': 'университет', 'img': 'img', 'src': 'src', '=': '=', '"': '"', 'https': 'https', ':': ':', 'sun': 'sun', '9-63': '9-63', 'userapi': 'userapi', 'com': 'com', '41': '41', 'TOBaIFmaF': 'tobaifmaf', '7': '7', 'jLK': 'jlk', '6': '6', 'tAzggm': 'tazggm', '0_bN_NGh': '0_bn_ngh' ...

# %%
import string
frequency = {}
text_string = news_text.lower()
match_pattern = re.findall(r'\b[а-я]{3,15}\b', text_string)
for word in match_pattern:
    count = frequency.get(word,0)
    frequency[word] = count + 1

# print(frequency)    

max = 0
frequency_sort = {}
for el in frequency:
  if frequency[el] >= max:
    frequency_sort[el] = frequency[el] 
    max = frequency[el]


print('Топ 5 слов')
for i in frequency_sort:
  print(frequency_sort[i], "-", i)

 




#for words in frequency_list:
#    print(words, frequency[words])
# Out:
# Топ 5 слов
# 2 - этом
# 4 - году
# 5 - педагогических
# 5 - сезонов
# 7 - что

# %%
from wordcloud import WordCloud

doc.ner.print()
# Out:
# В этом году пандемия внесла коррективы во многие планы. Однако все
# равно не смогла помешать открытию вторых летних Педагогических
# сезонов.Открытие состоялось в формате онлайн, к которому за последние
# месяцы мы все уже привыкли. Тем более, что тема первой дискуссии –
# Старт первым Сезонам в прошлом году давал губернатор Санкт-Петербурга.
#              PER────                                 LOC─────────────
#  В этом году с вступительным словом к участникам, партнерам и
# организаторам проекта обратился <em>«Мне почётно быть в партнерстве с
# вами, с теми, кто действительно делает актуальную педагогику в нашем
# городе, готовит и выпускает учителей, и кто олицетворяет одну из
# старейших и развитых педагогических школ нашей страны</em>Анализируя
# опыт Сезонов прошлого года, вице-губернатор сказал, что Герценовский
#                                                         ORG──────────
# университет показал возможности контактной педагогики, в очередной раз
# ───────────
#  став активным участником жизни города.Ректор РГПУ им. А. И. Герцена
#                                               ORG────────────────────
# Он также анонсировал открытие 1 сентября «Точки кипения» — живого
# ──
# пространства для встреч и общения и пообещал, что программа будет
# очень интересной.Сергей Игоревич выразил надежду, что в ближайшее
#                  PER────────────
# время мы все вернемся к привычному для нас формату реального общения и
#  рассказал, что вскоре исторические ворота XYIII века на Мойке, 48
#                                                          LOC──
# будут открыты для посетителей Педагогических сезонов.<em>«Мы по-
# прежнему остаемся открытым кампусом, даже более открытым, чем это было
#  раньше. Потому что сейчас мы видим новые возможности, которые
# возникли в ситуации ограничений»</em>Завершил официальную часть
# открытия проректор Герценовского университета  <img src="https://sun9-
#                    ORG───────────────────────
# 63.userapi.com/41TOBaIFmaF7jLK6tAzggm0_bN_NGh7Hbohtow/p8Bmoxpwfsc.jpg"
#  style="height:281px; width:500px"/> <em>«Нельзя закрыть знания на
# замок, нельзя не обращать внимание на то, что происходит вокруг. Мы
# хотим быть полезными своим опытом и знаниями в решении ваших задач и
# проблем. Мы бы хотели, чтобы в рамках Педагогических сезонов вы нашли
# своего «значимого взрослого» — того, кто поможет вам стать лучше,
# опытнее, в чем-то осведомлённее, чтобы вы развивали свои компетенции и
#  стремились к тому уровню, который действительно будет достойным
# результатом ваших трудов и работ»,</em>Дальнейшая дискуссия, которая
# собственно и дала старт Сезонам этого года, была посвящена достижениям
#                         PER────
#  в области внедрения новых форматов обучения. Представители
# профессионального сообщества приняли участие в диалоге, а также
# обсудили, как в наступающем учебном году будут применяться
# дистанционные форматы в школах и вузах нашей
# страны.<strong>Поздравляем всех с началом новых Педагогических сезонов
#  и ждем вас в нашем виртуальном кампусе!</strong>

# %%
for span in doc.spans:
    span.normalize(morph_vocab)
print(doc.spans[:5])

names = {_.text: _.normal for _ in doc.spans} # именованные сущности из новостной статьи 
print(names)
namesList = list(names.keys())
#print(namesList)
namesStr = ""
for el in namesList:
  namesStr = namesStr + ' ' + el
print(namesStr)
frequencyList = list(frequency_sort.keys())
wordsStr = ""
for el in frequencyList:
  wordsStr = wordsStr + ' ' + el
print(wordsStr)
#print(frequencyList)
# Out:
# [DocSpan(start=280, stop=287, type='PER', text='Сезонам', tokens=[...], normal='Сезонам'), DocSpan(start=320, stop=336, type='LOC', text='Санкт-Петербурга', tokens=[...], normal='Санкт-Петербург'), DocSpan(start=728, stop=752, type='ORG', text='Герценовский университет', tokens=[...], normal='Герценовский университет'), DocSpan(start=857, stop=882, type='ORG', text='РГПУ им. А. И. Герцена Он', tokens=[...], normal='РГПУ имя. А. И. Герцена Он'), DocSpan(start=1029, stop=1044, type='PER', text='Сергей Игоревич', tokens=[...], normal='Сергей Игоревич')]
# {'Сезонам': 'Сезонам', 'Санкт-Петербурга': 'Санкт-Петербург', 'Герценовский университет': 'Герценовский университет', 'РГПУ им. А. И. Герцена Он': 'РГПУ имя. А. И. Герцена Он', 'Сергей Игоревич': 'Сергей Игоревич', 'Мойке': 'Мойке', 'Герценовского университета': 'Герценовский университет'}
#  Сезонам Санкт-Петербурга Герценовский университет РГПУ им. А. И. Герцена Он Сергей Игоревич Мойке Герценовского университета
#  этом году педагогических сезонов что

# %%
wc1 = WordCloud().generate(namesStr)
import matplotlib.pyplot as plt
plt.imshow(wc1, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
wc2 = WordCloud().generate(wordsStr)
import matplotlib.pyplot as plt
plt.imshow(wc2, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)
